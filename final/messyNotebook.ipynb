# %%
#https://chronicdata.cdc.gov/500-Cities-Places/PLACES-Local-Data-for-Better-Health-Place-Data-202/eav7-hnsx
import pandas as pd
df = pd.read_csv('PLACES__Local_Data_for_Better_Health__County_Data_2020_release.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\matth\desktop\cisc367\cisc367_dir\venv\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     264         #  (xint or xbool) and (yint or bool)
# --> 265         result = op(x, y)
#     266     except TypeError:
#
# c:\users\matth\desktop\cisc367\cisc367_dir\venv\lib\site-packages\pandas\core\ops\roperator.py in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#      53
#
# TypeError: unsupported operand type(s) for &: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\users\matth\desktop\cisc367\cisc367_dir\venv\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     278             try:
# ...

# %%
df[(df['StateDesc']=='Alabama') & (df['LocationName']=='Bibb')]
# Out:
#        Year StateAbbr StateDesc LocationName DataSource             Category  \
# 1      2018        AL   Alabama         Bibb      BRFSS      Health Outcomes
# 888    2018        AL   Alabama         Bibb      BRFSS      Health Outcomes
# 1260   2018        AL   Alabama         Bibb      BRFSS      Health Outcomes
# 1514   2018        AL   Alabama         Bibb      BRFSS           Prevention
# 1593   2018        AL   Alabama         Bibb      BRFSS      Health Outcomes
# 2713   2018        AL   Alabama         Bibb      BRFSS           Prevention
# 3592   2018        AL   Alabama         Bibb      BRFSS  Unhealthy Behaviors
# 3737   2017        AL   Alabama         Bibb      BRFSS      Health Outcomes
# 4098   2018        AL   Alabama         Bibb      BRFSS           Prevention
# 4157   2018        AL   Alabama         Bibb      BRFSS           Prevention
# 4731   2018        AL   Alabama         Bibb      BRFSS           Prevention
# ...
